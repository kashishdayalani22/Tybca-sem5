# %%
from nltk.chat.util import Chat, reflections
my_dummy_reflections = {
    "mr" : "Doctor",
    "hello" : "hey there",
    "play" : "played"
}

pairs = [
    [
        r"my name is (.*)",
        ["Hello %1, How are you today ?",]
    ],
    [
        r"quit",
        ["BBye take care. See yu soon :)","It was nice talking to you, See you soon :)"]
    ],
]

def chatty():
  print("Hi, I'm Chatty and i chat alot:)\nPlease type lowercase English language to start a conveersation. Type quit to leave")
  chat = Chat(pairs, my_dummy_reflections)
  chat.converse()
if __name__ == "__main__":
  chatty()
# Out:
# Hi, I'm Chatty and i chat alot:)
# Please type lowercase English language to start a conveersation. Type quit to leave
# >my name is futurfutur
# Hello futurfutur, How are you today ?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_949/3866787929.py in <cell line: 0>()
#      22   chat.converse()
#      23 if __name__ == "__main__":
# ---> 24   chatty()
#
# /tmp/ipykernel_949/3866787929.py in chatty()
#      20   print("Hi, I'm Chatty and i chat alot:)\nPlease type lowercase English language to start a conveersation. Type quit to leave")
#      21   chat = Chat(pairs, my_dummy_reflections)
# ---> 22   chat.converse()
#      23 if __name__ == "__main__":
#      24   chatty()
#
# /usr/local/lib/python3.12/dist-packages/nltk/chat/util.py in converse(self, quit)
#     116             user_input = quit
#     117             try:
# --> 118                 user_input = input(">")
#     119             except EOFError:
#     120                 print(user_input)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
from nltk.chat.util import Chat, reflections
pairs = [
    [
        r"my name is (.*)",
        ["Hello %1, How are you today ?",]
    ],
     [
        r"what is your name ?",
        ["My name is Chatty and I'm a chatbot ?",]
    ],
    [
        r"how are you ?",
        ["I'm doing good\nHow about You ?",]
    ],
    [
        r"sorry (.*)",
        ["Its alright","Its OK, never mind",]
    ],
    [
        r"i'm (.*) doing good",
        ["Nice to hear that","Alright :)",]
    ],
    [
        r"hi|hey|hello",
        ["Hello", "Hey there",]
    ],
    [
        r"(.*) age?",
        ["I'm a computer program dude\nSeriously you are asking me this?",]

    ],
    [
        r"what (.*) want ?",
        ["Make me an offer I can't refuse",]

    ],
    [
        r"(.*) created ?",
        ["Nagesh created me using Python's NLTK library ","top secret ;)",]
    ],
    [
        r"(.*) (location|city) ?",
        ['Vadodara, Gujarat',]
    ],
    [
        r"how is weather in (.*)?",
        ["Weather in %1 is awesome like always","Too hot man here in %1","Too cold man here in %1","Never even heard about %1"]
    ],
    [
        r"i work in (.*)?",
        ["%1 is an Amazing company, I have heard about it. But they are in huge loss these days.",]
    ],
    [
        r"(.*)raining in (.*)",
        ["No rain since last week here in %2","Damn its raining too much here in %2"]
    ],
    [
        r"how (.*) health(.*)",
        ["I'm a computer program, so I'm always healthy ",]
    ],
    [
        r"(.*) (sports|game) ?",
        ["I'm a very big fan of Football",]
    ],
    [
        r"who (.*) sportsperson ?",
        ["Messy","Ronaldo","Roony"]
    ],
    [
        r"who (.*) (moviestar|actor)?",
        ["Brad Pitt"]
    ],
    [
        r"quit",
        ["BBye take care. See you soon :) ","It was nice talking to you. See you soon :)"]
    ],
        ]
def chatty():
        print("Hi, I'm Chatty and I chat alot ;)\nPlease type lowercase English language to start a conversation. Type quit to leave ") #default message at the start
        chat = Chat(pairs, reflections)
        chat.converse()
if __name__ == "__main__":

    chatty()
# Out:
# Hi, I'm Chatty and I chat alot ;)
# Please type lowercase English language to start a conversation. Type quit to leave
# >how is weather in abc
# Too hot man here in abc
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_949/1391949115.py in <cell line: 0>()
#      82 if __name__ == "__main__":
#      83
# ---> 84     chatty()
#
# /tmp/ipykernel_949/1391949115.py in chatty()
#      79         print("Hi, I'm Chatty and I chat alot ;)\nPlease type lowercase English language to start a conversation. Type quit to leave ") #default message at the start
#      80         chat = Chat(pairs, reflections)
# ---> 81         chat.converse()
#      82 if __name__ == "__main__":
#      83
#
# /usr/local/lib/python3.12/dist-packages/nltk/chat/util.py in converse(self, quit)
#     116             user_input = quit
#     117             try:
# --> 118                 user_input = input(">")
#     119             except EOFError:
#     120                 print(user_input)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
from nltk.chat.util import Chat, reflections
my_dummy_reflections= {
    "mr"     : "Doctor",
    "hello"    : "hey there",
    "play" : "played"
}
pairs = [
    [
        r"my name is (.*)",
        ["Hello %1, How are you today ?",]
    ],
     [
        r"Have you (.*)",
        ["I never %1",]
    ],
    [
        r"quit",
        ["BBye take care. See you soon :) ","It was nice talking to you. See you soon :)"]

    ],
]
def chatty():
        print("Hi, I'm Chatty and I chat alot ;)\nPlease type lowercase English language to start a conversation. Type quit to leave ") #default message at the start
        chat = Chat(pairs, my_dummy_reflections)
        chat.converse()
if __name__ == "__main__":

    chatty()
# Out:
# Hi, I'm Chatty and I chat alot ;)
# Please type lowercase English language to start a conversation. Type quit to leave
# >have you kicked anubhav
# I never kicked anubhav
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_949/2961821200.py in <cell line: 0>()
#      26 if __name__ == "__main__":
#      27
# ---> 28     chatty()
#
# /tmp/ipykernel_949/2961821200.py in chatty()
#      23         print("Hi, I'm Chatty and I chat alot ;)\nPlease type lowercase English language to start a conversation. Type quit to leave ") #default message at the start
#      24         chat = Chat(pairs, my_dummy_reflections)
# ---> 25         chat.converse()
#      26 if __name__ == "__main__":
#      27
#
# /usr/local/lib/python3.12/dist-packages/nltk/chat/util.py in converse(self, quit)
#     116             user_input = quit
#     117             try:
# --> 118                 user_input = input(">")
#     119             except EOFError:
#     120                 print(user_input)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
from nltk.chat.util import Chat, reflections

# Custom reflections (optional)
my_dummy_reflections = {
    "mr": "Doctor",
    "hello": "hey there",
    "play": "played"
}

# Define Q&A pairs for the e-commerce chatbot
pairs = [
    [
        r"my name is (.*)",
        ["Hello %1, welcome to our store! How can I help you today?"]
    ],
    [
        r"how do i create an account",
        ["Click on 'Sign Up' at the top right corner, enter your details, and verify your email."]
    ],
    [
        r"do i need an account to shop",
        ["You can browse without an account, but you’ll need one to place orders and track deliveries."]
    ],
    [
        r"how do i search for products",
        ["Use the search bar at the top of the page and type in the product name or category."]
    ],
    [
        r"can i save items for later",
        ["Yes, click the 'Add to Wishlist' button on any product page."]
    ],
    [
        r"how do i place an order",
        ["Select your product, choose quantity, click 'Add to Cart,' and proceed to checkout."]
    ],
    [
        r"what payment methods do you accept",
        ["We accept credit/debit cards, UPI, net banking, and digital wallets."]
    ],
    [
        r"is cash on delivery available",
        ["Yes, COD is available for most locations. You’ll see the option at checkout."]
    ],
    [
        r"can i use multiple discount codes",
        ["Only one discount code can be applied per order."]
    ],
    [
        r"how do i track my order",
        ["Go to 'My Orders' in your account dashboard and click 'Track Order.'"]
    ],
    [
        r"how long does delivery take",
        ["Standard delivery takes 3–5 business days, while express delivery is 1–2 days."]
    ],
    [
        r"do you ship internationally",
        ["Currently, we ship only within India."]
    ],
    [
        r"can i change my delivery address",
        ["Yes, you can update your address within 1 hour of placing the order."]
    ],
    [
        r"what if i miss my delivery",
        ["Our courier will attempt delivery again. You can also reschedule via the tracking page."]
    ],
    [
        r"what is your return policy",
        ["You can return products within 7 days of delivery if they are unused and in original packaging."]
    ],
    [
        r"how do i initiate a return",
        ["Go to 'My Orders,' select the product, and click 'Return/Replace.'"]
    ],
    [
        r"when will i get my refund",
        ["Refunds are processed within 5–7 business days after the returned item is received."]
    ],
    [
        r"can i exchange a product",
        ["Yes, exchanges are available for size or color variations, subject to stock availability."]
    ],
    [
        r"how do i contact customer service",
        ["You can reach us via live chat, email at support@shoponline.com, or call 1800-123-4567."]
    ],
    [
        r"what are your customer service hours",
        ["Our team is available Monday–Saturday, 9 AM to 9 PM IST."]
    ],
    [
        r"do you have a loyalty program",
        ["Yes, you earn points on every purchase that can be redeemed for discounts."]
    ],
    [
        r"quit",
        ["BBye take care. See you soon :)", "It was nice talking to you, see you soon :)"]
    ],
]

def chatty():
    print("Hi, I'm ShopBot, your e-commerce assistant! \nType lowercase English to chat. Type 'quit' to leave.")
    chat = Chat(pairs, my_dummy_reflections)
    chat.converse()

if __name__ == "__main__":
    chatty()
# Out:
# Hi, I'm ShopBot, your e-commerce assistant!
# Type lowercase English to chat. Type 'quit' to leave.
# >what payment methods do you accept
# We accept credit/debit cards, UPI, net banking, and digital wallets.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_949/3712392809.py in <cell line: 0>()
#     106
#     107 if __name__ == "__main__":
# --> 108     chatty()
#
# /tmp/ipykernel_949/3712392809.py in chatty()
#     103     print("Hi, I'm ShopBot, your e-commerce assistant! \nType lowercase English to chat. Type 'quit' to leave.")
#     104     chat = Chat(pairs, my_dummy_reflections)
# --> 105     chat.converse()
#     106
#     107 if __name__ == "__main__":
#
# /usr/local/lib/python3.12/dist-packages/nltk/chat/util.py in converse(self, quit)
#     116             user_input = quit
#     117             try:
# --> 118                 user_input = input(">")
#     119             except EOFError:
#     120                 print(user_input)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
from nltk.chat.util import Chat, reflections

# Custom reflections (optional)
my_dummy_reflections = {
    "mr": "Doctor",
    "hello": "hey there",
    "play": "played"
}

# Define Q&A pairs for the educational institution chatbot
pairs = [
    [
        r"my name is (.*)",
        ["Hello %1, welcome to our institution! How can I assist you today?"]
    ],
    [
        r"how do i apply for admission",
        ["You can apply online through our admission portal by filling out the application form."]
    ],
    [
        r"what courses do you offer",
        ["We offer undergraduate, postgraduate, and diploma programs across arts, science, commerce, and technology."]
    ],
    [
        r"what is the admission deadline",
        ["The admission deadline is usually June 30th. Please check the admission portal for exact dates."]
    ],
    [
        r"do you offer scholarships",
        ["Yes, we provide merit-based and need-based scholarships. Details are available on the scholarships page."]
    ],
    [
        r"what are the eligibility criteria for undergraduate programs",
        ["You must have completed 12th grade with the required percentage depending on the program."]
    ],
    [
        r"how can i contact the admission office",
        ["You can email admissions@institution.com or call 1800-111-222."]
    ],
    [
        r"what is the fee structure",
        ["The fee structure varies by program. You can view detailed fees on the 'Fees & Finance' section of our website."]
    ],
    [
        r"do you have hostel facilities",
        ["Yes, we provide separate hostel facilities for boys and girls with modern amenities."]
    ],
    [
        r"how do i apply for hostel",
        ["You can apply for hostel accommodation during the admission process by selecting the hostel option."]
    ],
    [
        r"what extracurricular activities are available",
        ["We offer sports, cultural clubs, debate societies, music, and drama activities."]
    ],
    [
        r"do you provide placement assistance",
        ["Yes, our placement cell helps students with internships and job opportunities."]
    ],
    [
        r"what companies visit for campus placements",
        ["Top companies from IT, finance, consulting, and manufacturing sectors visit our campus every year."]
    ],
    [
        r"how can i access the library",
        ["Students can access the library using their student ID card."]
    ],
    [
        r"do you have online learning resources",
        ["Yes, we provide e-books, journals, and online lectures through our digital library."]
    ],
    [
        r"what is the student-teacher ratio",
        ["Our average student-teacher ratio is 20:1, ensuring personalized attention."]
    ],
    [
        r"how do i get my transcripts",
        ["You can request transcripts from the registrar’s office or apply online."]
    ],
    [
        r"do you have international exchange programs",
        ["Yes, we have tie-ups with universities abroad for student exchange programs."]
    ],
    [
        r"how do i apply for exchange programs",
        ["You can apply through the international office with your academic records and statement of purpose."]
    ],
    [
        r"what are the office hours",
        ["Our administrative offices are open Monday to Friday, 9 AM to 5 PM."]
    ],
    [
        r"quit",
        ["BBye take care. See you soon :)", "It was nice talking to you, see you soon :)"]
    ],
]

def chatty():
    print("Hi, I'm EduBot, your academic assistant! \nPlease type lowercase English to chat. Type 'quit' to leave.")
    chat = Chat(pairs, my_dummy_reflections)
    chat.converse()

if __name__ == "__main__":
    chatty()
# Out:
# Hi, I'm EduBot, your academic assistant!
# Please type lowercase English to chat. Type 'quit' to leave.
# >what is the student-teacher ratio
# Our average student-teacher ratio is 20:1, ensuring personalized attention.
