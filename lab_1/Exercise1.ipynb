# %%
print("Hello World!")
# Out:
# Hello World!

# %%
if 5 > 2:
print("Five is greater than two")
# Out:
#   File "/tmp/ipykernel_952/4267780824.py", line 2
#     print("Five is greater than two")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
if 5 > 2:
  print("Five is greater than two!")
if 5 > 2:
    print("Five is greater than two!")
# Out:
# Five is greater than two!
# Five is greater than two!

# %%
if 5 > 2:
  print("Five is greater than two!")
    print("Five is greater than two!")
# Out:
#   File "/tmp/ipykernel_952/3814111980.py", line 3
#     print("Five is greater than two!")
#     ^
# IndentationError: unexpected indent

# %%
thislist = ["apple", "banana", "cherry"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry", "apple", "cherry"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'apple', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
print(thislist[1])
# Out:
# banana

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[2:5])
# Out:
# ['cherry', 'orange', 'kiwi']

# %%
thistuple = ("apple", "banana", "cherry")
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry')

# %%
thisset = {"apple", "banana", "cherry"}
print(thisset)
# Out:
# {'banana', 'cherry', 'apple'}

# %%
class MyClass:
  x = 5

# %%
p1 = MyClass()
print(p1.x)
# Out:
# 5

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

p1 = Person("abc", 19)
print(p1.name)
print(p1.age)
# Out:
# abc
# 19

# %%
class Point:
  def __init__(self, x = 0, y = 0):
    self.x = x
    self.y = y

  def add_points(self, other):
    x = self.x + other.x
    y = self.y + other.y
    return Point(x, y)

p1 = Point(1, 2)
p2 = Point(2, 3)

p3 = p1.add_points(p2)

print((p3.x , p3.y))
# Out:
# (3, 5)

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def __lt__(self, other):
    return self.age < other.age

p1 = Person("Alice", 20)
p2 = Person("Bob", 30)
print(p1 > p2)
print(p2 > p1)
# Out:
# False
# True

# %%
x= divmod(6, 2)
print(x)
# Out:
# (3, 0)
